# %% [markdown]
# # API Tests
#
# A collection of API tests that demonstrate how I test APIs.

# %% [markdown]
# ## Keanu Reeves Whoa API
#
# The tests here how I approach testing of an API when an item can be retrieved through an API, but additional information is needed.
#
# `test_whoa_retrieval` in [test_keanu_reeves_whoa.py](https://github.com/thoughtpenguin/JMB-Portfolio/blob/main/APITests/test_keanu_reeves_whoa.py) whos how I test it for this API: I first retrieve a random `whoa` (I promise that this is a technical term). I then retrieve the list of movies that contains a 'whoa'.  From there, I am able to retrieve a random `whoa` from each movie that occurs before the initial random `whoa`.  Since each `whoa` object contains information about the movie contains it (e.g. the count of `whoas` in the movie), I am able to calculate the `whoa` index.

# %%
import pytest
testName = "test_keanu_reeves_whoa"
pytest.main(['APITests/' + testName + '.py', '--html=' + testName + '.html'])
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-9.0.2, pluggy-1.6.0
# rootdir: /home/jberndt/Code/Portfolio/JMB-Portfolio
# configfile: pyproject.toml
# plugins: metadata-3.1.1, html-4.1.1, anyio-4.12.1
# collected 3 items
#
# APITests/test_keanu_reeves_whoa.py ...                                   [100%]
#
# - Generated html report: file:///home/jberndt/Code/Portfolio/JMB-Portfolio/test_keanu_reeves_whoa.html -
# ============================== 3 passed in 4.09s ===============================
# <ExitCode.OK: 0>

# %% [markdown]
# ## Open Library API

# %%
import pytest
testName = "test_open_library"
pytest.main(['APITests/' + testName + '.py', '--html=' + testName + '.html'])
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-9.0.2, pluggy-1.6.0
# rootdir: /home/jberndt/Code/Portfolio/JMB-Portfolio
# configfile: pyproject.toml
# plugins: metadata-3.1.1, html-4.1.1, anyio-4.12.1
# collected 4 items
#
# APITests/test_open_library.py ....                                       [100%]
#
# - Generated html report: file:///home/jberndt/Code/Portfolio/JMB-Portfolio/test_open_library.html -
# ============================== 4 passed in 1.84s ===============================
# <ExitCode.OK: 0>

# %% [markdown]
# # Selenium Tests
# All of the tests in this section test different functionality at [this website](https://the-internet.herokuapp.com/).
# ## Add and Remove Elements

# %%
import pytest
testName = "test_add_remove_elements"
pytest.main(['SeleniumTests/' + testName + '.py', '--html=' + testName + '.html'])
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-9.0.2, pluggy-1.6.0
# rootdir: /home/jberndt/Code/Portfolio/JMB-Portfolio
# configfile: pyproject.toml
# plugins: metadata-3.1.1, html-4.1.1, anyio-4.12.1
# collected 7 items
#
# SeleniumTests/test_add_remove_elements.py .......                        [100%]
#
# - Generated html report: file:///home/jberndt/Code/Portfolio/JMB-Portfolio/test_add_remove_elements.html -
# ============================== 7 passed in 31.19s ==============================
# <ExitCode.OK: 0>

# %% [markdown]
# ## Basic Authorization

# %%
import pytest
testName = "test_basic_auth"
pytest.main(['SeleniumTests/' + testName + '.py', '--html=' + testName + '.html'])
